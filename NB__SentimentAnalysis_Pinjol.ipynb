# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization purposes
import seaborn as sns # for statistical data visualization
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/KULIAH/SKRIPSI/DATASET/dataset_newLabelling2.xlsx')
df.head(3)
# Out:
#                                                 Text            Id  \
# 0  rt senilai rp miliar berhasil disita bareskrim...  1.461846e+18
# 1  rt bagaikan mati satu tumbuh seribu pinjol ill...  1.461846e+18
# 2  rt dittipideksus bareskrim polri akan mengenak...  1.461846e+18
#
#                                         tweet_tokens  \
# 0  [rt, senilai, rp, miliar, berhasil, disita, ba...
# 1  [rt, bagaikan, mati, satu, tumbuh, seribu, pin...
# 2  [rt, dittipideksus, bareskrim, polri, akan, me...
#
#                            tweet_tokens_fdist  \
# 0  <FreqDist with 17 samples and 17 outcomes>
# 1  <FreqDist with 17 samples and 18 outcomes>
# 2  <FreqDist with 18 samples and 18 outcomes>
#
#                                     tweet_tokens_WSW  \
# 0  [senilai, rp, miliar, berhasil, disita, baresk...
# 1  [mati, tumbuh, seribu, pinjol, illegal, punah,...
# 2  [dittipideksus, bareskrim, polri, mengenakan, ...
#
#                                     tweet_normalized  \
# 0  [senilai, rp, miliar, berhasil, disita, baresk...
# 1  [mati, tumbuh, seribu, pinjol, illegal, punah,...
# 2  [dittipideksus, bareskrim, polri, mengenakan, ...
#
#                                 tweet_tokens_stemmed  Cluster
# 0  [nila, rp, miliar, hasil, sita, bareskrim, pol...        0
# 1  [mati, tumbuh, ribu, pinjol, illegal, punah, p...        0
# 2  [dittipideksus, bareskrim, polri, kena, wna, b...        0

# %%
df.shape
# Out:
# (6907, 8)

# %%
df.drop(['Id'], axis=1, inplace=True)

# %%
df.head(3)
# Out:
#                                                 Text  \
# 0  rt senilai rp miliar berhasil disita bareskrim...
# 1  rt bagaikan mati satu tumbuh seribu pinjol ill...
# 2  rt dittipideksus bareskrim polri akan mengenak...
#
#                                         tweet_tokens  \
# 0  [rt, senilai, rp, miliar, berhasil, disita, ba...
# 1  [rt, bagaikan, mati, satu, tumbuh, seribu, pin...
# 2  [rt, dittipideksus, bareskrim, polri, akan, me...
#
#                            tweet_tokens_fdist  \
# 0  <FreqDist with 17 samples and 17 outcomes>
# 1  <FreqDist with 17 samples and 18 outcomes>
# 2  <FreqDist with 18 samples and 18 outcomes>
#
#                                     tweet_tokens_WSW  \
# 0  [senilai, rp, miliar, berhasil, disita, baresk...
# 1  [mati, tumbuh, seribu, pinjol, illegal, punah,...
# 2  [dittipideksus, bareskrim, polri, mengenakan, ...
#
#                                     tweet_normalized  \
# 0  [senilai, rp, miliar, berhasil, disita, baresk...
# 1  [mati, tumbuh, seribu, pinjol, illegal, punah,...
# 2  [dittipideksus, bareskrim, polri, mengenakan, ...
#
#                                 tweet_tokens_stemmed  Cluster
# 0  [nila, rp, miliar, hasil, sita, bareskrim, pol...        0
# 1  [mati, tumbuh, ribu, pinjol, illegal, punah, p...        0
# 2  [dittipideksus, bareskrim, polri, kena, wna, b...        0

# %%
df.shape
# Out:
# (6907, 7)

# %%
from wordcloud import WordCloud, STOPWORDS
from nltk.corpus import stopwords

comment_words = ''
stopwords = ''

for val in df['tweet_tokens_stemmed']:
  # typecaste each val to string
  val = str(val)

  # split the value
  tokens = val.split()

  for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()
  
  comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width=800, height=800,
                      background_color = "white", stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

plt.figure(figsize=(8,6), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# TF - IDF Pembobotan

# %%
#TF-IDF Pembobotan
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer

vectorizer = CountVectorizer()
transformer = TfidfTransformer()

x = vectorizer.fit_transform(df.tweet_tokens_stemmed)
print(f"shape >> {x.toarray().shape}")
print("samples\n")
print(x.toarray()[0])

x = transformer.fit_transform(x)
print(f"\n\nshape >> {x.toarray().shape}")
print("samples\n")
print(x.toarray()[0])

X = x.toarray()
y = df.Cluster
# Out:
# shape >> (6907, 6220)
# samples
#
# [0 0 0 ... 0 0 0]
#
#
# shape >> (6907, 6220)
# samples
#
# [0. 0. 0. ... 0. 0. 0.]

# %% [markdown]
# Train and Test Split Data

# %%
#TRAIN and TEST SPLIT DATA
from sklearn.model_selection import train_test_split

train_data,test_data,train_label,test_label = train_test_split(X,y,test_size=0.3,random_state=42)

print("Train Data shape : ",train_data.shape)
print("Test Data shape : ",test_data.shape)
print("Train Label shape : ",train_label.shape)
print("Test Label shape : ",test_label.shape)
# Out:
# Train Data shape :  (4834, 6220)
# Test Data shape :  (2073, 6220)
# Train Label shape :  (4834,)
# Test Label shape :  (2073,)

# %% [markdown]
# Confusion Matrix for Accuracy

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import plot_confusion_matrix
from matplotlib import pyplot

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

models_NB = []
models_NB.append(GaussianNB())
models_NB.append(MultinomialNB())
models_NB.append(BernoulliNB())

for model in models_NB:
    model.fit(train_data,train_label)
    pred = model.predict(test_data)
    acc = accuracy_score(test_label,pred)
    print(f"Model {model.__class__.__name__} accuracy on test dataset >> {acc}")
# Out:
# Model GaussianNB accuracy on test dataset >> 0.9585142305836951
# Model MultinomialNB accuracy on test dataset >> 0.9942112879884226
# Model BernoulliNB accuracy on test dataset >> 0.9956584659913169

# %% [markdown]
# Bernoulli Naive Bayes

# %%
#nb = GaussianNB()
#nb = MultinomialNB()
nb = BernoulliNB()

nb.fit(test_data, test_label)
y_pred = nb.predict(test_data)

# %%
print(confusion_matrix(test_label, y_pred))
# Out:
# [[1677    5]
#  [   1  390]]

# %%
print(accuracy_score(test_label, y_pred))
# Out:
# 0.9971056439942113

# %%
print(classification_report(test_label,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1682
#            1       0.99      1.00      0.99       391
#
#     accuracy                           1.00      2073
#    macro avg       0.99      1.00      1.00      2073
# weighted avg       1.00      1.00      1.00      2073

# %% [markdown]
# Classification Accuracy

# %%
cm = confusion_matrix(test_label, y_pred)

TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]

# %%
# print classification accuracy

classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.9971

# %% [markdown]
# Precision

# %%
# print precision score
precision = TP / float(TP + FP)
print('Precision : {0:0.4f}'.format(precision))
# Out:
# Precision : 0.9970

# %% [markdown]
# Recall

# %%
# print recall score
recall = TP / float(TP + FN)
print('Recall or Sensitivity : {0:0.4f}'.format(recall))
# Out:
# Recall or Sensitivity : 0.9994

# %% [markdown]
# Error Rate

# %%
# print classification error
classification_error = (FP + FN) / float(TP + TN + FP + FN)
print('Classification error : {0:0.4f}'.format(classification_error))
# Out:
# Classification error : 0.0029
